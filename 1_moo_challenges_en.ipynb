# %% [markdown]
# <a href="https://colab.research.google.com/github/tinodiplotti/Personal-/blob/main/1_moo_challenges_en.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practice: Abstract Data Types and Object-Oriented Programming Challenges
#
# In this practice session, you will review Python data types and work with **Abstract Data Types (ADTs)**, classes, objects, encapsulation, inheritance, polymorphism, and basic modeling.
#
# The challenges progress from short review exercises to small design and implementation problems.

# %% [markdown]
# ## How to Complete This Practice Session
#
# Each challenge includes:
#
# - 🎯 **Objective**
# - 🕒 **Estimated time**
# - 🟢🟡🔴 **Difficulty**
# - 🧠 Questions to think about before programming
# - 💡 Hints when needed
# - ✅ Automatic tests with `assert`
#
# First run your solution cell and then run the test cell.

# %% [markdown]
# > ## 📌 Practice Rules
# >
# > - Complete only the areas marked with `TODO`.
# > - Do not modify the test cells.
# > - Use clear names for attributes, methods, and variables.
# > - Run the cells in order.

# %% [markdown]
# ## Automatic Checking
#
# The test cells include `assert` statements.
#
# If all tests pass, you will see:
#
# ```text
# Tests passed
# ```
#
# If any test fails, review your implementation before continuing.
#
# If you need to review how `assert` works, see:
#
# https://github.com/isegura/ED/blob/main/resources/assert_en.ipynb

# %% [markdown]
# # 🏆 Challenge 1. Recognizing Python Types
#
# 🎯 **Objective:** Implement `python_type(value)` to return the name of the type of the received value.
#
# 🕒 **Estimated time:** 5 minutes
#
# 🟢 **Difficulty:** Easy
#
# The function must recognize these types:
#
# `int`, `float`, `bool`, `str`, `list`, `tuple`, `dict`, and `set`.
#
# The result must be a string with the type name.
#
# ### 🧠 Before Programming
# - What does `type(value)` return?
# - How can you obtain only the name of the type?
# - Remember that `bool` is also a Python type.

# %%
def python_type(value):
    # TODO: return the name of the value's type
  if type(value) == int:
    return "int"
  elif type(value) == float:
    return "float"
  elif type(value) == bool:
    return "bool"
  elif type(value) == str:
    return "str"
  elif type(value) == list:
    return "list"
  elif type(value) == tuple:
    return "tuple"
  elif type(value) == dict:
    return "dict"
  elif type(value) == set:
    return "set"
  else:
    return "unknown"
  pass

# %% [markdown]
# Run the following cell to check your solution.

# %%
assert python_type(10) == "int"
assert python_type(3.5) == "float"
assert python_type(True) == "bool"
assert python_type("Ana") == "str"
assert python_type([1, 2]) == "list"
assert python_type((1, 2)) == "tuple"
assert python_type({"a": 1}) == "dict"
assert python_type({1, 2}) == "set"
print("Tests passed")
# Out:
# Tests passed

# %% [markdown]
# # 🏆 Challenge 2. Choosing the Right Data Type
#
# 🎯 **Objective:** Identify which Python data type is most appropriate for representing different situations.
#
# 🕒 **Estimated time:** 8 minutes
#
# 🟢 **Difficulty:** Easy
#
# ### 📋 Statement
#
# For each of the following situations, indicate **which Python data type you would use** (`int`, `float`, `bool`, `str`, `list`, `dict`, `set`, or `tuple`) and **briefly justify your choice**.
#
# - Age of a person
# - Price of a product
# - State of a light bulb (on/off)
# - Name of a student
# - List of grades for a course
# - Information about a student (name, email, and age)
# - Set of unique user identifiers

# %% [markdown]
# Write your answers in the following table. Add a justification.
#
# | Situation | Data type | Justification |
# |-----------|-----------|---------------|
# | Age of a person |int |Must be a number and its not regularly written with decimals |
# | Price of a product |float |Must be a number and can contain cents so itsnmore appropiate than an integer |
# | State of a light bulb (on/off) |bool|Bools represent two states, true or false |
# | Name of a student |str|Names are written with sequences of characters|
# | List of grades for a course |list|List are useful to store some items|
# | Information about a student (name, email, and age) |dict |Because you can store data about each element|
# | Set of unique user identifiers |set|Must be a list but since the identifiers are unique, it must be a set where elements are not repeated |

# %% [markdown]
# # 🏆 Challenge 3. Do We Need a New Data Type?
#
# 🎯 **Objective:** Identify when Python data types are sufficient and when it is useful to define a new Abstract Data Type (ADT).
#
# 🕒 **Estimated time:** 8 minutes
#
# 🟢 **Difficulty:** Easy
#
# ### 📋 Statement
#
# For each of the following situations, indicate whether it would be enough to use the data types provided by Python (`int`, `str`, `list`, `dict`, etc.) or whether it would be more appropriate to design a new **Abstract Data Type (ADT)**.
#
# - A list of integers
# - A student (name, email, courses, and average grade)
# - A traffic light
# - A dictionary that stores countries and capitals
# - A bank account with deposit and withdrawal operations
# - A complex number
#
# ### 🧠 Before Answering
#
# - Do you only need to store information, or do you also need to define specific operations?
# - Does the entity have its own behavior?
# - Are basic and compound Python types enough to represent it?

# %% [markdown]
# Add your answer to the following table:
#
# | Situation | Python types or ADT? | Justification |
# |-----------|----------------------|---------------|
# | A list of integers |Python types |A list of integers can be easily reperesented by creating a list and adding integer numbers |
# | A student (name, email, courses, and average grade) |ADT|By creating a class where the attributes are the data of the elements|
# | A traffic light |ADT|To make the whole functioning of the traffic lught it is necessary to use a class|
# | A dictionary that stores countries and capitals |Python types|Its done with a dictionary in which the keys are the countries and the elements the capitals|
# | A bank account with deposit and withdrawal operations|ADT|We need a class to create functions with deposit and withdrawal operations|
# | A complex number |ADT|To describe the behaviour of a complex number an ADT would be required because python types cannot describe it |

# %% [markdown]
# # 🏆 Challenge 4. Identifying Attributes and Methods
#
# 🎯 **Objective:** Differentiate between the attributes and methods of an Abstract Data Type.
#
# 🕒 **Estimated time:** 10 minutes
#
# 🟡 **Difficulty:** Medium
#
# ### 📋 Statement
#
# We want to design an **ADT Music Player**.
#
# Classify each of the following elements as an **attribute** or a **method**.
#
# - Volume
# - Current song
# - State (playing or paused)
# - Play
# - Pause
# - Increase volume
# - Decrease volume
# - Song duration
#
# ### 🧠 Before Answering
#
# - Attributes store information about the object's state.
# - Methods represent actions that modify that state or provide some service.

# %% [markdown]
# Classify each of the following elements as an **attribute** or a **method**. Complete the following table:
#
# | Element | Attribute or method? |
# |---------|----------------------|
# | Volume |Attribute |
# | Current song |Atributte|
# | State (playing or paused) |Attribute |
# | Play |Method|
# | Pause |Method|
# | Increase volume |Method |
# | Decrease volume |Method |
# | Song duration |Attribute |

# %% [markdown]
# # 🏆 Challenge 5. Designing an ADT Scoreboard
#
# 🎯 **Objective:** Identify the attributes and methods of an Abstract Data Type.
#
# 🕒 **Estimated time:** 10 minutes
#
# 🟡 **Difficulty:** Medium
#
# ### 📋 Statement
#
# We want to design an **ADT Scoreboard** to represent the score of a football match.
#
# A scoreboard must store the number of goals scored by the home team and by the away team. It must also allow the score to be updated when a goal is scored and allow the current score to be checked.
#
# Complete the following table indicating which elements are **attributes** and which are **methods**.
#
# | Element | Attribute or method? |
# |---------|----------------------|
# | Home team goals |Attribute |
# | Away team goals |Attribute |
# | Score a home goal |Method |
# | Score an away goal |Method |
# | Check score |Method |
# | Reset scoreboard |Method |

# %% [markdown]
# # 🏆 Challenge 6. Implementing the ADT Scoreboard
#
# 🎯 **Objective:** Implement an Abstract Data Type using a Python class.
#
# 🕒 **Estimated time:** 20 minutes
#
# 🟡 **Difficulty:** Medium
#
# ### 📋 Statement
#
# In the previous challenge, you identified the attributes and methods of the **ADT Scoreboard**, which represents the score of a football match.
#
# Now implement the `Scoreboard` class in Python.
#
# The class must include:
#
# - A constructor that receives the number of goals scored by the home team and the away team.
# - The attributes:
#   - `home_goals`
#   - `away_goals`
# - A method `home_goal()` that increases the home team's goals by one.
# - A method `away_goal()` that increases the away team's goals by one.
# - A method `score()` that returns a string with the score in the format:
#
# ```text
# home_goals - away_goals
# ```
#
# For example:
#
# ```python
# scoreboard = Scoreboard(1, 0)
#
# scoreboard.home_goal()
# scoreboard.away_goal()
# scoreboard.away_goal()
#
# print(scoreboard.score())
# ```
#
# Expected output:
#
# ```text
# 2 - 2
# ```
#
# ### 🧠 Before You Start
#
# - Remember that the constructor must initialize the object's state.
# - The `home_goal()` and `away_goal()` methods modify that state.
# - The `score()` method does not modify the object; it only returns a representation of the scoreboard.

# %%
class Scoreboard:
  def __init__(self, home_goals, away_goals):
    self.home_goals= home_goals
    self.away_goals= away_goals

  def home_goal(self):
    self.home_goals+= 1

  def away_goal(self):
    self.away_goals+= 1

  def score(self):
    return str(self.home_goals) + " - " + str(self.away_goals )

# %% [markdown]
# Run the following cell to check your solution.

# %%
scoreboard = Scoreboard(1, 0)

assert scoreboard.home_goals == 1
assert scoreboard.away_goals == 0

scoreboard.home_goal()
assert scoreboard.home_goals == 2
assert scoreboard.away_goals == 0

scoreboard.away_goal()
scoreboard.away_goal()

assert scoreboard.home_goals == 2
assert scoreboard.away_goals == 2

assert scoreboard.score() == "2 - 2"

print("Tests passed")
# Out:
# Tests passed

# %% [markdown]
# # 🏆 Challenge 7. Creating Several `Scoreboard` Objects
#
# 🎯 **Objective:** Understand that each object created from a class keeps its own state.
#
# 🕒 **Estimated time:** 10 minutes
#
# 🟢 **Difficulty:** Easy
#
# ### 📋 Statement
#
# Use the `Scoreboard` class implemented in the previous challenge to represent two different matches.
#
# You must:
#
# 1. Create a scoreboard for a first match that starts with the score `0 - 0`.
# 2. Create another scoreboard for a second match that starts with the score `1 - 0`.
# 3. Add two goals to the home team in the first match.
# 4. Add one goal to the away team in the second match.
# 5. Display the score of both matches using the `score()` method.
#
# Check that changes made to one scoreboard do not affect the other.
#
# The final result must be:
#
# ```text
# Match 1: 2 - 0
# Match 2: 1 - 1
# ```
#
# ### 🧠 Before You Start
#
# - Each call to the constructor creates a different object.
# - Each object keeps its own values for `home_goals` and `away_goals`.
# - Modifying one object must not change the state of the other objects.

# %%
match1 = Scoreboard(0, 0)
match2 = Scoreboard(1, 0)

match1.home_goal()
match1.home_goal()

match2.away_goal()

print("Match 1: ", match1.score())
print("Match 2: ", match2.score())
# Out:
# Match 1:  2 - 0
# Match 2:  1 - 1

# %% [markdown]
# # 🏆 Challenge 8. Encapsulation
#
# 🎯 **Objective:** Implement a `Thermostat` class that ensures the temperature stays within a valid range.
#
# 🕒 **Estimated time:** 15 minutes
#
# 🟡 **Difficulty:** Medium
#
# The class must include:
#
# - attribute `temperature`. When a Thermostat object is created, its default temperature will be 5."
#
# - method `set_temperature(new_temperature)`
# - method `get_temperature()`
#
# Only temperatures between `5` and `35` degrees, both included, will be accepted.
# `set_temperature` must return `True` if it changes the value and `False` if it rejects it.
#
# ### 🧠 Before Programming
# - The validation must be inside the method.
# - If the value is invalid, the object's state must be preserved.

# %%
class Thermostat:

    def __init__(self):
       self.temperature= 20

    def set_temperature(self, new_temperature):
        if (new_temperature >= 5 and new_temperature <= 35):
          self.temperature= new_temperature
          return True
        else:
          return False

    def get_temperature(self):
        return self.temperature

# %% [markdown]
# Run the following cell to check your solution.

# %%
thermostat = Thermostat()

assert thermostat.get_temperature() == 20
assert thermostat.set_temperature(25) is True
assert thermostat.get_temperature() == 25

assert thermostat.set_temperature(40) is False
assert thermostat.get_temperature() == 25

assert thermostat.set_temperature(5) is True
assert thermostat.set_temperature(35) is True
print("Tests passed")
# Out:
# Tests passed

# %% [markdown]
# # 🏆 Challenge 9. Inheritance
#
# 🎯 **Objective:** Complete a simple hierarchy formed by `Animal`, `Dog`, and `Cat`.
#
# 🕒 **Estimated time:** 12 minutes
#
# 🟡 **Difficulty:** Medium
#
# The base class `Animal` will store `name`.
#
# Each subclass must implement `make_sound()`:
#
# - `Dog` returns `"woof"`
# - `Cat` returns `"meow"`
#
# ### 🧠 Before Programming
# - What attribute do the subclasses share?
# - Use `super()` to reuse the base class constructor.

# %%
class Animal:

    def __init__(self, name):
        self.name= name


class Dog(Animal):

    def __init__(self, name):
        super().__init__(name)


    def make_sound(self):
        return "woof"


class Cat(Animal):

    def __init__(self, name):
        super().__init__(name)

    def make_sound(self):
        return "meow"

# %% [markdown]
# Run the following cell to check your solution.

# %%
dog = Dog("Luna")
cat = Cat("Milo")

assert dog.name == "Luna"
assert cat.name == "Milo"
assert dog.make_sound() == "woof"
assert cat.make_sound() == "meow"
assert isinstance(dog, Animal)
assert isinstance(cat, Animal)
print("Tests passed")
# Out:
# Tests passed

# %% [markdown]
# # 🏆 Challenge 10. Polymorphism
#
# 🎯 **Objective:** Implement a function that works with different objects that share the same operation.
#
# 🕒 **Estimated time:** 10 minutes
#
# 🟡 **Difficulty:** Medium
#
# Implement `sounds(animals)`.
#
# The function receives a list of objects and returns a list with the result of calling `make_sound()` on each one.
#
# ### 🧠 Before Programming
# - The function does not need to check whether each object is a dog or a cat.
# - It is enough that all of them provide the same method.

# %%
def sounds(animals):
  animals_sounds= []
  for x in animals:
    animals_sounds.append(x.make_sound())

  return animals_sounds

# %% [markdown]
# Run the following cell to check your solution.

# %%
class Dog:
    def make_sound(self):
        return "woof"

class Cat:
    def make_sound(self):
        return "meow"

class Bird:
    def make_sound(self):
        return "tweet"

animals = [Dog(), Cat(), Bird()]
assert sounds(animals) == ["woof", "meow", "tweet"]
assert sounds([]) == []
print("Tests passed")
# Out:
# Tests passed

# %% [markdown]
# # 🏆 Challenge 11. Debugging a Class
#
# 🎯 **Objective:** Fix the errors in the `Product` class.
#
# 🕒 **Estimated time:** 12 minutes
#
# 🟡 **Difficulty:** Medium
#
# The class must:
#
# - store `name` and `price`
# - allow a percentage discount to be applied
# - reject discounts lower than `0` or greater than `100`
# - return `True` when the discount is applied and `False` when it is rejected
#
# ### 🧠 Before Programming
# Look for errors related to:
#
# - use of `self`
# - modification of attributes
# - data validation

# %%
class Product:

    def __init__(self, name, price):
        self.name = name
        self.price = price

    def apply_discount(self, percentage):
        if percentage >= 0 and percentage <= 100:
            self.price = self.price - self.price * percentage / 100
            return True

        return False

# %% [markdown]
# Run the following cell to check your solution.

# %%
product = Product("Keyboard", 80)

assert product.name == "Keyboard"
assert product.price == 80

assert product.apply_discount(25) is True
assert product.price == 60

assert product.apply_discount(-10) is False
assert product.price == 60

assert product.apply_discount(120) is False
assert product.price == 60
print("Tests passed")
# Out:
# Tests passed

# %% [markdown]
# # 🏆 Challenge 12. Implementing the ADT Complex Number
#
# 🎯 **Objective:** Implement a simple class to represent complex numbers.
#
# 🕒 **Estimated time:** 20 minutes
#
# 🔴 **Difficulty:** Difficult
#
# The `ComplexNumber` class must store:
#
# - `real`
# - `imaginary`
#
# It must implement:
#
# - `add(other)`, which returns a new `ComplexNumber`
# - `subtract(other)`, which returns a new `ComplexNumber`
# - `modulus()`, which returns its modulus
#
# ### 🧠 Before Programming
# For a complex number `a + bi`:
#
# - addition and subtraction are performed component by component;
# - the modulus is `(a? + b?) ** 0.5`.

# %%
class ComplexNumber:

    def __init__(self, real, imaginary):
        self.real= real
        self.imaginary= imaginary

    def add(self, other):
        new_cnum= ComplexNumber(0,0)
        new_cnum.real= self.real + other.real
        new_cnum.imaginary= self.imaginary + other.imaginary

        return new_cnum

    def subtract(self, other):
        new_cnum= ComplexNumber(0,0)
        new_cnum.real= self.real - other.real
        new_cnum.imaginary= self.imaginary - other.imaginary

        return new_cnum

    def modulus(self):
        return (self.real**2 + self.imaginary**2)**0.5

# %% [markdown]
# Run the following cell to check your solution.

# %%
z1 = ComplexNumber(3, 4)
z2 = ComplexNumber(1, -2)

sum_result = z1.add(z2)
difference = z1.subtract(z2)

assert isinstance(sum_result, ComplexNumber)
assert sum_result.real == 4
assert sum_result.imaginary == 2

assert difference.real == 2
assert difference.imaginary == 6

assert z1.modulus() == 5
print("Tests passed")
# Out:
# Tests passed

# %% [markdown]
# # 🏆 Challenge 13. Modeling a Library
#
# 🎯 **Objective:** Represent a simplified version of a loan system using classes.
#
# 🕒 **Estimated time:** 25 minutes
#
# 🔴 **Difficulty:** Difficult
#
# Implement:
#
# ### `Book`
#
# Attributes:
#
# - `isbn`
# - `title`
# - `available`, initially `True`
#
# ### `User`
#
# Attributes:
#
# - `identifier`
# - `name`
# - `loans`, initially an empty list
#
# Methods:
#
# - `borrow(book)`: borrows the book if it is available
# - `return_book(book)`: returns a borrowed book
#
# The methods must return `True` when the operation is performed and `False` otherwise.
#
# ### 🧠 Before Programming
# - When a book is borrowed, it must no longer be available.
# - The same book cannot be borrowed twice at the same time.
# - When it is returned, it must be removed from the loans list and become available again.

# %%
class Book:

    def __init__(self, isbn, title):
        self.isbn= isbn
        self.title= title
        self.available= True


class User:

    def __init__(self, identifier, name):
        self.identifier= identifier
        self.name= name
        self.loans=[]

    def borrow(self, book):
        if book.available == True:
          self.loans.append(book)
          book.available= False
          return True

        return False

    def return_book(self, book):
        if book not in self.loans:
          return False
        else:
          self.loans.remove(book)
          book.available= True
          return True

# %% [markdown]
# Run the following cell to check your solution.

# %%
book = Book("978-1", "Data Structures")
ana = User("U01", "Ana")
luis = User("U02", "Luis")

assert book.available is True
assert ana.loans == []

assert ana.borrow(book) is True
assert book.available is False
assert book in ana.loans

assert luis.borrow(book) is False
assert book not in luis.loans

assert ana.return_book(book) is True
assert book.available is True
assert book not in ana.loans

assert ana.return_book(book) is False
print("Tests passed")
# Out:
# Tests passed

# %% [markdown]
# # 🎉 End of the Practice Session
#
# You have reviewed Python types and worked with:
#
# - Abstract Data Types
# - classes and objects
# - encapsulation
# - inheritance
# - polymorphism
# - design and implementation of small data structures
